# %% [markdown]
# <a href="https://colab.research.google.com/github/emraankazmi5-coder/deeplearning/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Install & Imports

# %%
# !pip install kagglehub -q

import os
import kagglehub
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.manifold import TSNE

print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.19.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Download Dataset

# %%
path = kagglehub.dataset_download("msambare/fer2013")
print("Path to dataset:", path)
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.
# Path to dataset: /kaggle/input/fer2013

# %% [markdown]
# Setup & Count Images

# %%
EMOTION_LABELS = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
train_dir = os.path.join(path, 'train')
test_dir  = os.path.join(path, 'test')

print("Training set distribution:")
for emo in EMOTION_LABELS:
    emo_path = os.path.join(train_dir, emo)
    if os.path.exists(emo_path):
        count = len(os.listdir(emo_path))
        print(f"  {emo:10s}: {count} images")
# Out:
# Training set distribution:
#   angry     : 3995 images
#   disgust   : 436 images
#   fear      : 4097 images
#   happy     : 7215 images
#   neutral   : 4965 images
#   sad       : 4830 images
#   surprise  : 3171 images

# %% [markdown]
# Configration

# %%
# 1: increase resolution of original images (48 -> 96)
#  2: bottleneck should be > 256 ( 512)
# 3: train longer (60 epochs)

IMG_SIZE   = 96    # Upscaled from 48x48 to 96x96 for better resolution
LATENT_DIM = 512   #  using 512
BATCH_SIZE = 64
EPOCHS     = 60    # Train longer than before (was 50)

print(f"Image size  : {IMG_SIZE}x{IMG_SIZE}")
print(f"Latent dim  : {LATENT_DIM}  ( recommended >256)")
print(f"Epochs      : {EPOCHS}      (training longer for better quality)")
# Out:
# Image size  : 96x96
# Latent dim  : 512  ( recommended >256)
# Epochs      : 60      (training longer for better quality)

# %% [markdown]
#  Collect Image Paths

# %%
def collect_image_paths(base_dir, emotion_labels):
    paths, labels = [], []
    for idx, emo in enumerate(emotion_labels):
        emo_dir = os.path.join(base_dir, emo)
        if not os.path.exists(emo_dir):
            continue
        for fname in os.listdir(emo_dir):
            if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                paths.append(os.path.join(emo_dir, fname))
                labels.append(idx)
    return np.array(paths), np.array(labels)

train_paths, train_labels = collect_image_paths(train_dir, EMOTION_LABELS)
test_paths,  test_labels  = collect_image_paths(test_dir,  EMOTION_LABELS)

print(f"Total train images: {len(train_paths)}")
print(f"Total test  images: {len(test_paths)}")
# Out:
# Total train images: 28709
# Total test  images: 7178

# %% [markdown]
# Image Loading (Upscaled to 96x96)

# %%
def load_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=1, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img

train_ds = tf.data.Dataset.from_tensor_slices(train_paths)
train_ds = train_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.shuffle(5000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Sample batch shape:", next(iter(train_ds)).shape)
# Out:
# Sample batch shape: (64, 96, 96, 1)

# %% [markdown]
# Visualize Sample Images

# %%
fig, axes = plt.subplots(2, 7, figsize=(18, 6))
fig.suptitle("FER2013 — Sample Images per Emotion (Upscaled to 96x96)", fontsize=14, fontweight='bold')

for col, emo in enumerate(EMOTION_LABELS):
    emo_paths = train_paths[train_labels == col]
    for row in range(2):
        img = load_image(emo_paths[row]).numpy().squeeze()
        axes[row, col].imshow(img, cmap='gray')
        axes[row, col].axis('off')
        if row == 0:
            axes[row, col].set_title(emo.capitalize(), fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Build Encoder

# %%
# Simpler architecture to avoid NaN instability
encoder_inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 1), name='encoder_input')

x = layers.Conv2D(32,  3, strides=2, padding='same')(encoder_inputs)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2D(64,  3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2D(128, 3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2D(256, 3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Flatten()(x)
x = layers.Dense(1024)(x)
x = layers.LeakyReLU(0.2)(x)

# Bottleneck 512 as professor instructed (>256)
z_mean    = layers.Dense(LATENT_DIM, name='z_mean',
                kernel_initializer='glorot_uniform')(x)
z_log_var = layers.Dense(LATENT_DIM, name='z_log_var',
                kernel_initializer='glorot_uniform')(x)

def sampling(args):
    z_mean, z_log_var = args
    z_log_var_clipped = tf.clip_by_value(z_log_var, -2, 2)
    epsilon = tf.random.normal(shape=tf.shape(z_mean))
    return z_mean + tf.exp(0.5 * z_log_var_clipped) * epsilon

z = layers.Lambda(sampling, name='z')([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 96, 96, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 48, 48,    │        320 │ encoder_input[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 48, 48,    │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# Build Decoder

# %%
# 96 / (2^4) = 6  so we start from 6x6
latent_inputs = keras.Input(shape=(LATENT_DIM,), name='latent_input')

x = layers.Dense(6 * 6 * 256, kernel_initializer='glorot_uniform')(latent_inputs)
x = layers.LeakyReLU(0.2)(x)
x = layers.Reshape((6, 6, 256))(x)

x = layers.Conv2DTranspose(256, 3, strides=2, padding='same')(x)   # 12
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2DTranspose(128, 3, strides=2, padding='same')(x)   # 24
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2DTranspose(64,  3, strides=2, padding='same')(x)   # 48
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2DTranspose(32,  3, strides=2, padding='same')(x)   # 96
x = layers.LeakyReLU(0.2)(x)

# Sigmoid output to keep pixels between 0 and 1
decoder_outputs = layers.Conv2DTranspose(1, 3, padding='same',
                      activation='sigmoid')(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ latent_input (InputLayer)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 9216)           │     4,727,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 12, 12, 256)    │       590,080 │
# ...

# %% [markdown]
# VAE Model with MSE Loss

# %%
class EmotionVAE(keras.Model):
    def __init__(self, encoder, decoder, beta=0.00005, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta    = beta
        self.total_loss_tracker = keras.metrics.Mean(name='total_loss')
        self.recon_loss_tracker = keras.metrics.Mean(name='recon_loss')
        self.kl_loss_tracker    = keras.metrics.Mean(name='kl_loss')

    @property
    def metrics(self):
        return [self.total_loss_tracker,
                self.recon_loss_tracker,
                self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data, training=True)
            reconstruction = self.decoder(z, training=True)

            # MSE reconstruction loss — normalized by image size
            recon_loss = tf.reduce_mean(
                tf.square(data - reconstruction)
            ) * (IMG_SIZE * IMG_SIZE)

            # Stable KL loss — clip log_var before exp
            z_log_var_c = tf.clip_by_value(z_log_var, -2, 2)
            z_mean_c    = tf.clip_by_value(z_mean,    -5, 5)
            kl_loss = -0.5 * tf.reduce_mean(
                1 + z_log_var_c
                  - tf.square(z_mean_c)
                  - tf.exp(z_log_var_c)
            )

            total_loss = recon_loss + self.beta * kl_loss

            # Safety check — if NaN appears, skip update
            total_loss = tf.where(
                tf.math.is_nan(total_loss),
                tf.zeros_like(total_loss),
                total_loss
            )

        grads = tape.gradient(total_loss, self.trainable_weights)
        # Clip every gradient
        grads = [tf.clip_by_value(g, -1.0, 1.0)
                 if g is not None else g for g in grads]
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.recon_loss_tracker.update_state(recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {m.name: m.result() for m in self.metrics}

# %% [markdown]
# Train the VAE (60 Epochs)

# %%
# Very small learning rate for stability
optimizer = keras.optimizers.Adam(
    learning_rate=2e-5,   # very small
    epsilon=1e-7,         # numerical stability
    clipnorm=0.5
)

vae = EmotionVAE(encoder, decoder, beta=0.00005)
vae.compile(optimizer=optimizer)

# Quick sanity check before full training
print("Running 1 epoch sanity check...")
test_history = vae.fit(train_ds, epochs=1, verbose=1)
first_loss = test_history.history['total_loss'][0]
print(f"\nFirst epoch loss: {first_loss}")

if str(first_loss) == 'nan':
    print("STILL NaN — check data pipeline")
else:
    print("Loss is valid! Running full 60 epochs...")
    history = vae.fit(train_ds, epochs=59, verbose=1)
    # Combine both runs
    for key in history.history:
        history.history[key] = test_history.history[key] + history.history[key]
# Out:
# Running 1 epoch sanity check...
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 70s 133ms/step - kl_loss: 4.3121 - recon_loss: 496.7212 - total_loss: 496.7215
#
# First epoch loss: 496.72149658203125
# Loss is valid! Running full 60 epochs...
# Epoch 1/59
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 23s 46ms/step - kl_loss: 5.8607 - recon_loss: 230.3678 - total_loss: 230.3681
# Epoch 2/59
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 23s 47ms/step - kl_loss: 6.9617 - recon_loss: 171.9791 - total_loss: 171.9794
# Epoch 3/59
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - kl_loss: 7.0152 - recon_loss: 151.4603 - total_loss: 151.4605
# Epoch 4/59
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - kl_loss: 6.8798 - recon_loss: 137.9362 - total_loss: 137.9366
# Epoch 5/59
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - kl_loss: 6.6799 - recon_loss: 127.5163 - total_loss: 127.5166
# Epoch 6/59
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - kl_loss: 6.4745 - recon_loss: 118.9222 - total_loss: 118.9225
# Epoch 7/59
# ...

# %% [markdown]
# Training Loss Curves

# %%
print("Keys:", list(history.history.keys()))
print("Total epochs recorded:", len(history.history['total_loss']))

import numpy as np
for key, vals in history.history.items():
    arr = np.array(vals)
    print(f"{key}: min={np.nanmin(arr):.4f}  max={np.nanmax(arr):.4f}  NaNs={np.isnan(arr).sum()}")

fig, axes = plt.subplots(1, 3, figsize=(18, 4))
fig.suptitle('Training Loss Curves (60 Epochs)', fontsize=14, fontweight='bold')

keys   = ['total_loss', 'recon_loss', 'kl_loss']
colors = ['steelblue',  'darkorange', 'green']
titles = ['Total Loss', 'Reconstruction Loss (MSE)', 'KL Loss']

for ax, key, color, title in zip(axes, keys, colors, titles):
    vals = np.array(history.history[key])
    # Replace NaN with previous valid value for plotting
    for i in range(len(vals)):
        if np.isnan(vals[i]) and i > 0:
            vals[i] = vals[i-1]
    ax.plot(vals, color=color, linewidth=2)
    ax.set_title(title)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Keys: ['kl_loss', 'recon_loss', 'total_loss']
# Total epochs recorded: 60
# kl_loss: min=4.3121  max=7.9906  NaNs=0
# recon_loss: min=46.2625  max=496.7212  NaNs=0
# total_loss: min=46.2627  max=496.7215  NaNs=0
