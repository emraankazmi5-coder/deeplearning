# %% [markdown]
# <a href="https://colab.research.google.com/github/emraankazmi5-coder/deeplearning/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub -q

import os
import kagglehub
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.manifold import TSNE

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
path = kagglehub.dataset_download("msambare/fer2013")
print("Dataset path:", path)
# Out:
# Using Colab cache for faster access to the 'fer2013' dataset.
# Dataset path: /kaggle/input/fer2013

# %%
import os
import numpy as np

EMOTION_LABELS = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
train_dir = os.path.join(path, 'train')
test_dir  = os.path.join(path, 'test')

print("Training set distribution:")
for emo in EMOTION_LABELS:
    emo_path = os.path.join(train_dir, emo)
    if os.path.exists(emo_path):
        print(f"  {emo:10s}: {len(os.listdir(emo_path))} images")
# Out:
# Training set distribution:
#   angry     : 3995 images
#   disgust   : 436 images
#   fear      : 4097 images
#   happy     : 7215 images
#   neutral   : 4965 images
#   sad       : 4830 images
#   surprise  : 3171 images

# %%
IMG_SIZE   = 96    # Upscaled from 48 to 96 for better resolution
LATENT_DIM = 512   # Professor said >256
BATCH_SIZE = 64
EPOCHS     = 60    # Train longer

print(f"Image Size  : {IMG_SIZE}x{IMG_SIZE}  (upscaled from 48x48)")
print(f"Latent Dim  : {LATENT_DIM}           (professor recommended >256)")
print(f"Max Epochs  : {EPOCHS}               (with early stopping)")
# Out:
# Image Size  : 96x96  (upscaled from 48x48)
# Latent Dim  : 512           (professor recommended >256)
# Max Epochs  : 60               (with early stopping)

# %%
def collect_image_paths(base_dir, emotion_labels):
    paths, labels = [], []
    for idx, emo in enumerate(emotion_labels):
        emo_dir = os.path.join(base_dir, emo)
        if not os.path.exists(emo_dir):
            continue
        for fname in os.listdir(emo_dir):
            if fname.lower().endswith(('.png', '.jpg', '.jpeg')):
                paths.append(os.path.join(emo_dir, fname))
                labels.append(idx)
    return np.array(paths), np.array(labels)

train_paths, train_labels = collect_image_paths(train_dir, EMOTION_LABELS)
test_paths,  test_labels  = collect_image_paths(test_dir,  EMOTION_LABELS)

print(f"Train: {len(train_paths)} images")
print(f"Test : {len(test_paths)} images")
# Out:
# Train: 28709 images
# Test : 7178 images

# %%
def load_image(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=1, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    return img

train_ds = tf.data.Dataset.from_tensor_slices(train_paths)
train_ds = train_ds.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.shuffle(5000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Batch shape:", next(iter(train_ds)).shape)
# Out:
# Batch shape: (64, 96, 96, 1)

# %%
fig, axes = plt.subplots(2, 7, figsize=(18, 6))
fig.suptitle("FER2013 — Sample Images per Emotion (96x96)", fontsize=14, fontweight='bold')

for col, emo in enumerate(EMOTION_LABELS):
    emo_paths = train_paths[train_labels == col]
    for row in range(2):
        img = load_image(emo_paths[row]).numpy().squeeze()
        axes[row, col].imshow(img, cmap='gray')
        axes[row, col].axis('off')
        if row == 0:
            axes[row, col].set_title(emo.capitalize(), fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# 96 -> 48 -> 24 -> 12 -> 6 (four stride-2 layers)
encoder_inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 1), name='encoder_input')

x = layers.Conv2D(32,  3, strides=2, padding='same')(encoder_inputs)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2D(64,  3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2D(128, 3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2D(256, 3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Flatten()(x)
x = layers.Dense(1024)(x)
x = layers.LeakyReLU(0.2)(x)

z_mean    = layers.Dense(LATENT_DIM, name='z_mean',
                kernel_initializer='glorot_uniform')(x)
z_log_var = layers.Dense(LATENT_DIM, name='z_log_var',
                kernel_initializer='glorot_uniform')(x)

def sampling(args):
    z_mean, z_log_var = args
    z_log_var_clipped = tf.clip_by_value(z_log_var, -2, 2)
    epsilon = tf.random.normal(shape=tf.shape(z_mean))
    return z_mean + tf.exp(0.5 * z_log_var_clipped) * epsilon

z = layers.Lambda(sampling, name='z')([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_input       │ (None, 96, 96, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 48, 48,    │        320 │ encoder_input[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 48, 48,    │          0 │ conv2d_4[0][0]    │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 24, 24,    │     18,496 │ leaky_re_lu_10[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 24, 24,    │          0 │ conv2d_5[0][0]    │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 12, 12,    │     73,856 │ leaky_re_lu_11[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 12, 12,    │          0 │ conv2d_6[0][0]    │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 6, 6, 256) │    295,168 │ leaky_re_lu_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 6, 6, 256) │          0 │ conv2d_7[0][0]    │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 9216)      │          0 │ leaky_re_lu_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1024)      │  9,438,208 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 1024)      │          0 │ dense_2[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 512)       │    524,800 │ leaky_re_lu_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 512)       │    524,800 │ leaky_re_lu_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Lambda)          │ (None, 512)       │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,875,648 (41.49 MB)
#  Trainable params: 10,875,648 (41.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 6 -> 12 -> 24 -> 48 -> 96
latent_inputs = keras.Input(shape=(LATENT_DIM,), name='latent_input')

x = layers.Dense(6 * 6 * 256, kernel_initializer='glorot_uniform')(latent_inputs)
x = layers.LeakyReLU(0.2)(x)
x = layers.Reshape((6, 6, 256))(x)

x = layers.Conv2DTranspose(256, 3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2DTranspose(128, 3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2DTranspose(64,  3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

x = layers.Conv2DTranspose(32,  3, strides=2, padding='same')(x)
x = layers.LeakyReLU(0.2)(x)

decoder_outputs = layers.Conv2DTranspose(1, 3, padding='same',
                      activation='sigmoid')(x)

decoder = keras.Model(latent_inputs, decoder_outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ latent_input (InputLayer)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9216)           │     4,727,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 12, 12, 256)    │       590,080 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 24, 24, 128)    │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 48, 48, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 96, 96, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 96, 96, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 96, 96, 1)      │           289 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,705,473 (21.76 MB)
#  Trainable params: 5,705,473 (21.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class EmotionVAE(keras.Model):
    def __init__(self, encoder, decoder, beta=0.00005, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta    = beta
        self.total_loss_tracker = keras.metrics.Mean(name='total_loss')
        self.recon_loss_tracker = keras.metrics.Mean(name='recon_loss')
        self.kl_loss_tracker    = keras.metrics.Mean(name='kl_loss')

    @property
    def metrics(self):
        return [self.total_loss_tracker,
                self.recon_loss_tracker,
                self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data, training=True)
            reconstruction       = self.decoder(z, training=True)

            # MSE loss
            recon_loss = tf.reduce_mean(
                tf.square(data - reconstruction)
            ) * (IMG_SIZE * IMG_SIZE)

            # Stable KL loss
            z_log_var_c = tf.clip_by_value(z_log_var, -2, 2)
            z_mean_c    = tf.clip_by_value(z_mean,    -5, 5)
            kl_loss = -0.5 * tf.reduce_mean(
                1 + z_log_var_c - tf.square(z_mean_c) - tf.exp(z_log_var_c)
            )

            total_loss = recon_loss + self.beta * kl_loss
            total_loss = tf.where(tf.math.is_nan(total_loss),
                                  tf.zeros_like(total_loss), total_loss)

        grads = tape.gradient(total_loss, self.trainable_weights)
        grads = [tf.clip_by_value(g, -1.0, 1.0)
                 if g is not None else g for g in grads]
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.recon_loss_tracker.update_state(recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {m.name: m.result() for m in self.metrics}

# %%
optimizer = keras.optimizers.Adam(
    learning_rate=2e-5,
    epsilon=1e-7,
    clipnorm=0.5
)

# Early stopping — stops if no improvement for 5 epochs
early_stopping = keras.callbacks.EarlyStopping(
    monitor='total_loss',
    patience=5,
    restore_best_weights=False,
    verbose=1,
    mode='min'
)

# Cut learning rate in half if loss plateaus for 3 epochs
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='total_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1,
    mode='min'
)

vae = EmotionVAE(encoder, decoder, beta=0.00005)
vae.compile(optimizer=optimizer)

history = vae.fit(
    train_ds,
    epochs=60,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

print(f"\nStopped at epoch : {len(history.history['total_loss'])}")
print(f"Best total loss  : {min(history.history['total_loss']):.4f}")
# Out:
# Epoch 1/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 43s 67ms/step - kl_loss: 7.5478 - recon_loss: 155.5870 - total_loss: 155.5874 - learning_rate: 2.0000e-05
# Epoch 2/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 7.4888 - recon_loss: 132.8972 - total_loss: 132.8976 - learning_rate: 2.0000e-05
# Epoch 3/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 7.1772 - recon_loss: 120.3472 - total_loss: 120.3475 - learning_rate: 2.0000e-05
# Epoch 4/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.8635 - recon_loss: 110.9002 - total_loss: 110.9005 - learning_rate: 2.0000e-05
# Epoch 5/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.5945 - recon_loss: 103.6515 - total_loss: 103.6518 - learning_rate: 2.0000e-05
# Epoch 6/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.3622 - recon_loss: 97.5802 - total_loss: 97.5806 - learning_rate: 2.0000e-05
# Epoch 7/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 57ms/step - kl_loss: 6.1661 - recon_loss: 92.5007 - total_loss: 92.5010 - learning_rate: 2.0000e-05
# Epoch 8/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.9952 - recon_loss: 88.2200 - total_loss: 88.2203 - learning_rate: 2.0000e-05
# Epoch 9/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 5.8576 - recon_loss: 84.4650 - total_loss: 84.4654 - learning_rate: 2.0000e-05
# Epoch 10/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.7527 - recon_loss: 81.1055 - total_loss: 81.1057 - learning_rate: 2.0000e-05
# Epoch 11/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 5.6616 - recon_loss: 78.1458 - total_loss: 78.1460 - learning_rate: 2.0000e-05
# Epoch 12/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.5934 - recon_loss: 75.3510 - total_loss: 75.3512 - learning_rate: 2.0000e-05
# Epoch 13/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 5.5515 - recon_loss: 72.7559 - total_loss: 72.7562 - learning_rate: 2.0000e-05
# Epoch 14/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.5137 - recon_loss: 70.4538 - total_loss: 70.4541 - learning_rate: 2.0000e-05
# Epoch 15/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.4934 - recon_loss: 68.3294 - total_loss: 68.3297 - learning_rate: 2.0000e-05
# Epoch 16/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.4817 - recon_loss: 66.4189 - total_loss: 66.4192 - learning_rate: 2.0000e-05
# Epoch 17/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.4809 - recon_loss: 64.5774 - total_loss: 64.5776 - learning_rate: 2.0000e-05
# Epoch 18/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - kl_loss: 5.4939 - recon_loss: 62.8645 - total_loss: 62.8648 - learning_rate: 2.0000e-05
# Epoch 19/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - kl_loss: 5.5028 - recon_loss: 61.3543 - total_loss: 61.3546 - learning_rate: 2.0000e-05
# Epoch 20/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.5039 - recon_loss: 59.9713 - total_loss: 59.9716 - learning_rate: 2.0000e-05
# Epoch 21/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.5002 - recon_loss: 58.6561 - total_loss: 58.6564 - learning_rate: 2.0000e-05
# Epoch 22/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.5087 - recon_loss: 57.4228 - total_loss: 57.4231 - learning_rate: 2.0000e-05
# Epoch 23/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.5340 - recon_loss: 56.2479 - total_loss: 56.2482 - learning_rate: 2.0000e-05
# Epoch 24/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.5536 - recon_loss: 55.1610 - total_loss: 55.1613 - learning_rate: 2.0000e-05
# Epoch 25/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.5879 - recon_loss: 54.1451 - total_loss: 54.1455 - learning_rate: 2.0000e-05
# Epoch 26/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.6203 - recon_loss: 53.2277 - total_loss: 53.2280 - learning_rate: 2.0000e-05
# Epoch 27/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.6313 - recon_loss: 52.3593 - total_loss: 52.3596 - learning_rate: 2.0000e-05
# Epoch 28/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.6632 - recon_loss: 51.5529 - total_loss: 51.5532 - learning_rate: 2.0000e-05
# Epoch 29/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.6949 - recon_loss: 50.7836 - total_loss: 50.7838 - learning_rate: 2.0000e-05
# Epoch 30/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.7152 - recon_loss: 50.0418 - total_loss: 50.0421 - learning_rate: 2.0000e-05
# Epoch 31/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.7657 - recon_loss: 49.3219 - total_loss: 49.3222 - learning_rate: 2.0000e-05
# Epoch 32/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - kl_loss: 5.8129 - recon_loss: 48.6360 - total_loss: 48.6363 - learning_rate: 2.0000e-05
# Epoch 33/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.8595 - recon_loss: 47.9786 - total_loss: 47.9789 - learning_rate: 2.0000e-05
# Epoch 34/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.8953 - recon_loss: 47.3494 - total_loss: 47.3497 - learning_rate: 2.0000e-05
# Epoch 35/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 5.9108 - recon_loss: 46.7314 - total_loss: 46.7317 - learning_rate: 2.0000e-05
# Epoch 36/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 5.9399 - recon_loss: 46.1476 - total_loss: 46.1480 - learning_rate: 2.0000e-05
# Epoch 37/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 5.9820 - recon_loss: 45.6106 - total_loss: 45.6109 - learning_rate: 2.0000e-05
# Epoch 38/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 31s 59ms/step - kl_loss: 6.0227 - recon_loss: 45.0618 - total_loss: 45.0621 - learning_rate: 2.0000e-05
# Epoch 39/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.0601 - recon_loss: 44.5499 - total_loss: 44.5502 - learning_rate: 2.0000e-05
# Epoch 40/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.0990 - recon_loss: 44.0407 - total_loss: 44.0411 - learning_rate: 2.0000e-05
# Epoch 41/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.1421 - recon_loss: 43.5846 - total_loss: 43.5849 - learning_rate: 2.0000e-05
# Epoch 42/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.1704 - recon_loss: 43.1116 - total_loss: 43.1119 - learning_rate: 2.0000e-05
# Epoch 43/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.2088 - recon_loss: 42.6740 - total_loss: 42.6743 - learning_rate: 2.0000e-05
# Epoch 44/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.2357 - recon_loss: 42.2633 - total_loss: 42.2636 - learning_rate: 2.0000e-05
# Epoch 45/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.2692 - recon_loss: 41.8514 - total_loss: 41.8517 - learning_rate: 2.0000e-05
# Epoch 46/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.3047 - recon_loss: 41.4669 - total_loss: 41.4672 - learning_rate: 2.0000e-05
# Epoch 47/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.3391 - recon_loss: 41.0649 - total_loss: 41.0653 - learning_rate: 2.0000e-05
# Epoch 48/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - kl_loss: 6.3724 - recon_loss: 40.6829 - total_loss: 40.6833 - learning_rate: 2.0000e-05
# Epoch 49/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.3955 - recon_loss: 40.3224 - total_loss: 40.3227 - learning_rate: 2.0000e-05
# Epoch 50/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.4251 - recon_loss: 39.9469 - total_loss: 39.9472 - learning_rate: 2.0000e-05
# Epoch 51/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.4665 - recon_loss: 39.6069 - total_loss: 39.6071 - learning_rate: 2.0000e-05
# Epoch 52/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.5034 - recon_loss: 39.2341 - total_loss: 39.2344 - learning_rate: 2.0000e-05
# Epoch 53/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.5396 - recon_loss: 38.8944 - total_loss: 38.8947 - learning_rate: 2.0000e-05
# Epoch 54/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.5569 - recon_loss: 38.5288 - total_loss: 38.5291 - learning_rate: 2.0000e-05
# Epoch 55/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.5963 - recon_loss: 38.1589 - total_loss: 38.1593 - learning_rate: 2.0000e-05
# Epoch 56/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.6242 - recon_loss: 37.8058 - total_loss: 37.8061 - learning_rate: 2.0000e-05
# Epoch 57/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.6554 - recon_loss: 37.4394 - total_loss: 37.4397 - learning_rate: 2.0000e-05
# Epoch 58/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.6868 - recon_loss: 37.0868 - total_loss: 37.0871 - learning_rate: 2.0000e-05
# Epoch 59/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 56ms/step - kl_loss: 6.7060 - recon_loss: 36.7257 - total_loss: 36.7261 - learning_rate: 2.0000e-05
# Epoch 60/60
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 57ms/step - kl_loss: 6.7383 - recon_loss: 36.3926 - total_loss: 36.3929 - learning_rate: 2.0000e-05
#
# Stopped at epoch : 60
# Best total loss  : 36.3929

# %%
print("Keys:", list(history.history.keys()))
print("Epochs recorded:", len(history.history['total_loss']))

fig, axes = plt.subplots(1, 3, figsize=(18, 4))
fig.suptitle('Training Loss Curves', fontsize=14, fontweight='bold')

keys   = ['total_loss', 'recon_loss', 'kl_loss']
colors = ['steelblue',  'darkorange', 'green']
titles = ['Total Loss', 'Reconstruction Loss (MSE)', 'KL Loss']

for ax, key, color, title in zip(axes, keys, colors, titles):
    vals = np.array(history.history[key])
    ax.plot(vals, color=color, linewidth=2)
    ax.set_title(title)
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Keys: ['kl_loss', 'recon_loss', 'total_loss', 'learning_rate']
# Epochs recorded: 60
